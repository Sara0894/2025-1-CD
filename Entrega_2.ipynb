# %% [markdown]
# <a href="https://colab.research.google.com/github/Sara0894/2025-1-CD/blob/main/Entrega_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # *DataFrame Numérico*

# %%
#DataFrame Numérico
df_numeric = pd.DataFrame([[1, 18], [2, 22], [3, 25], [4, 30], [5, 14], [6, 35], [7, 37], [8, 28], [9, 32], [10, 27]], columns= ['ID', 'Age'], index = ['A', 'B', 'C', 'D', 'E', 'F', 'J', 'H', 'I', 'J'])
print(df_numeric)
# Out:
#    ID  Age
# A   1   18
# B   2   22
# C   3   25
# D   4   30
# E   5   14
# F   6   35
# J   7   37
# H   8   28
# I   9   32
# J  10   27

# %%
df_numeric.head()
# Out:
#    ID  Age
# A   1   18
# B   2   22
# C   3   25
# D   4   30
# E   5   14

# %%
df_numeric.tail()
# Out:
#    ID  Age
# F   6   35
# J   7   37
# H   8   28
# I   9   32
# J  10   27

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, A to J
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Age     10 non-null     int64
# dtypes: int64(2)
# memory usage: 540.0+ bytes

# %%
df_numeric.dtypes
# Out:
# ID     int64
# Age    int64
# dtype: object

# %%
df_numeric.columns = ['Identification number', 'Longevity']
print(df_numeric)
# Out:
#    Identification number  Longevity
# A                      1         18
# B                      2         22
# C                      3         25
# D                      4         30
# E                      5         14
# F                      6         35
# J                      7         37
# H                      8         28
# I                      9         32
# J                     10         27

# %%
identity = df_numeric['Identification number']
print(identity)
# Out:
# A     1
# B     2
# C     3
# D     4
# E     5
# F     6
# J     7
# H     8
# I     9
# J    10
# Name: Identification number, dtype: int64

# %%
df_numeric[['Identification number', 'Longevity']]
# Out:
#    Identification number  Longevity
# A                      1         18
# B                      2         22
# C                      3         25
# D                      4         30
# E                      5         14
# F                      6         35
# J                      7         37
# H                      8         28
# I                      9         32
# J                     10         27

# %%
df_numeric[df_numeric['Longevity'] <= 30]
# Out:
#    Identification number  Longevity
# A                      1         18
# B                      2         22
# C                      3         25
# D                      4         30
# E                      5         14
# H                      8         28
# J                     10         27

# %%
df_numeric.loc['A']
# Out:
# Identification number     1
# Longevity                18
# Name: A, dtype: int64

# %%
operadorOr = df_numeric[(df_numeric['Identification number'] > 4) | (df_numeric['Longevity'] > 30)]
operadorAnd = df_numeric[(df_numeric['Identification number'] > 4) & (df_numeric['Longevity'] > 30)]

print(operadorOr)
print(operadorAnd)
# Out:
#    Identification number  Longevity
# E                      5         14
# F                      6         35
# J                      7         37
# H                      8         28
# I                      9         32
# J                     10         27
#    Identification number  Longevity
# F                      6         35
# J                      7         37
# I                      9         32

# %%
df_numeric['Number of siblings'] = [4, 3, 5, 1, 0, 1, 2, 6, 1, 0]
print(df_numeric)
# Out:
#    Identification number  Longevity  Number of siblings
# A                      1         18                   4
# B                      2         22                   3
# C                      3         25                   5
# D                      4         30                   1
# E                      5         14                   0
# F                      6         35                   1
# J                      7         37                   2
# H                      8         28                   6
# I                      9         32                   1
# J                     10         27                   0

# %%
mean1 = df_numeric['Identification number'].mean()
mean2 = df_numeric['Longevity'].mean()
mean3 = df_numeric['Number of siblings'].mean()
print(mean1)
print(mean2)
print(mean3)
# Out:
# 5.5
# 26.8
# 2.3

# %%
median1 = df_numeric['Identification number'].median()
median2 = df_numeric['Longevity'].median()
median3 = df_numeric['Number of siblings'].median()
print(median1)
print(median2)
print(median3)
# Out:
# 5.5
# 27.5
# 1.5

# %%
st1= df_numeric['Identification number'].std()
st2= df_numeric['Longevity'].std()
st3= df_numeric['Number of siblings'].std()
print(st1)
print(st2)
print(st3)
# Out:
# 3.0276503540974917
# 7.284687135812126
# 2.1108186931983415

# %%
min1 = df_numeric['Identification number'].min()
min2 = df_numeric['Longevity'].min()
min3 = df_numeric['Number of siblings'].min()
print(min1)
print(min2)
print(min3)
# Out:
# 1
# 14
# 0

# %%
max1 = df_numeric['Identification number'].max()
max2 = df_numeric['Longevity'].max()
max3 = df_numeric['Number of siblings'].max()
print(max1)
print(max2)
print(max3)
# Out:
# 10
# 37
# 6

# %%
df_numeric.describe()
# Out:
#        Identification number  Longevity  Number of siblings
# count               10.00000  10.000000           10.000000
# mean                 5.50000  26.800000            2.300000
# std                  3.02765   7.284687            2.110819
# min                  1.00000  14.000000            0.000000
# 25%                  3.25000  22.750000            1.000000
# 50%                  5.50000  27.500000            1.500000
# 75%                  7.75000  31.500000            3.750000
# max                 10.00000  37.000000            6.000000

# %%
df_numeric['Number of siblings'] = df_numeric['Number of siblings'].replace({
    4: 6,
    3: 2,
    5: 3,
    1: 4,
    0: 1,
    1: 0,
    2: 0,
    6: 5,
    1: 6,
    0: 4
})
print(df_numeric)
# Out:
#    Identification number  Longevity  Number of siblings
# A                      1         18                   6
# B                      2         22                   2
# C                      3         25                   3
# D                      4         30                   6
# E                      5         14                   4
# F                      6         35                   6
# J                      7         37                   0
# H                      8         28                   5
# I                      9         32                   6
# J                     10         27                   4

# %%
df_numeric = df_numeric.drop(columns = 'Number of siblings')
print(df_numeric)
# Out:
#    Identification number  Longevity
# A                      1         18
# B                      2         22
# C                      3         25
# D                      4         30
# E                      5         14
# F                      6         35
# J                      7         37
# H                      8         28
# I                      9         32
# J                     10         27

# %%
df_numeric = df_numeric.drop(index = 'E')
print(df_numeric)
# Out:
#    Identification number  Longevity
# A                      1         18
# B                      2         22
# C                      3         25
# D                      4         30
# F                      6         35
# J                      7         37
# H                      8         28
# I                      9         32
# J                     10         27

# %% [markdown]
# # *DataFrame Decimal*

# %%
df_decimals= pd.DataFrame([['Anna', 4.5, 4.0], ['Luis', 3.8, 3.5], ['Pedro', 4.2, 4.7], ['María', 3.0, 3.6], ['Carlos', 4.8, 4.9], ['Sofía', 2.9, 3.2], ['José', 3.7, 4.0], ['Elena', 4.1, 4.3], ['Juan', 4.0, 3.9], ['Lucía', 3.3, 3.1]], columns= ['Student', 'Note exam 1', 'Note exam 2'], index = ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X'])
print (df_decimals)
# Out:
#      Student  Note exam 1  Note exam 2
# I       Anna          4.5          4.0
# II      Luis          3.8          3.5
# III    Pedro          4.2          4.7
# IV     María          3.0          3.6
# V     Carlos          4.8          4.9
# VI     Sofía          2.9          3.2
# VII     José          3.7          4.0
# VIII   Elena          4.1          4.3
# IX      Juan          4.0          3.9
# X      Lucía          3.3          3.1

# %%
df_decimals.head()
# Out:
#     Student  Note exam 1  Note exam 2
# I      Anna          4.5          4.0
# II     Luis          3.8          3.5
# III   Pedro          4.2          4.7
# IV    María          3.0          3.6
# V    Carlos          4.8          4.9

# %%
df_decimals.tail()
# Out:
#      Student  Note exam 1  Note exam 2
# VI     Sofía          2.9          3.2
# VII     José          3.7          4.0
# VIII   Elena          4.1          4.3
# IX      Juan          4.0          3.9
# X      Lucía          3.3          3.1

# %%
df_decimals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, I to X
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student      10 non-null     object
#  1   Note exam 1  10 non-null     float64
#  2   Note exam 2  10 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 620.0+ bytes

# %%
df_decimals.dtypes
# Out:
# Student         object
# Note exam 1    float64
# Note exam 2    float64
# dtype: object

# %%
df_decimals.columns= ['Pupil','Qualification 1','Qualification 2']
print(df_decimals)
# Out:
#        Pupil  Qualification 1  Qualification 2
# I       Anna              4.5              4.0
# II      Luis              3.8              3.5
# III    Pedro              4.2              4.7
# IV     María              3.0              3.6
# V     Carlos              4.8              4.9
# VI     Sofía              2.9              3.2
# VII     José              3.7              4.0
# VIII   Elena              4.1              4.3
# IX      Juan              4.0              3.9
# X      Lucía              3.3              3.1

# %%
names = df_decimals['Qualification 1']
print (names)
# Out:
# I       4.5
# II      3.8
# III     4.2
# IV      3.0
# V       4.8
# VI      2.9
# VII     3.7
# VIII    4.1
# IX      4.0
# X       3.3
# Name: Qualification 1, dtype: float64

# %%
df_decimals[['Pupil','Qualification 2']]
# Out:
#        Pupil  Qualification 2
# I       Anna              4.0
# II      Luis              3.5
# III    Pedro              4.7
# IV     María              3.6
# V     Carlos              4.9
# VI     Sofía              3.2
# VII     José              4.0
# VIII   Elena              4.3
# IX      Juan              3.9
# X      Lucía              3.1

# %%
df_decimals[df_decimals['Qualification 1']<3.0]
# Out:
#     Pupil  Qualification 1  Qualification 2
# VI  Sofía              2.9              3.2

# %%
df_decimals.loc['V']
# Out:
# Pupil              Carlos
# Qualification 1       4.8
# Qualification 2       4.9
# Name: V, dtype: object

# %%
df_decimals[((df_decimals['Qualification 2']<=3.0) & (df_decimals['Qualification 1']<4.0))]
df_decimals[((df_decimals['Qualification 1']>3.5) | (df_decimals['Qualification 2']>4.5))]
# Out:
#        Pupil  Qualification 1  Qualification 2
# I       Anna              4.5              4.0
# II      Luis              3.8              3.5
# III    Pedro              4.2              4.7
# V     Carlos              4.8              4.9
# VII     José              3.7              4.0
# VIII   Elena              4.1              4.3
# IX      Juan              4.0              3.9

# %%
df_decimals['Qualification 3']=[4.1, 3.1, 4.7, 4.0, 3.8, 3.8, 4.2, 5.0, 3.0, 3.2]

print (df_decimals)
# Out:
#        Pupil  Qualification 1  Qualification 2  Qualification 3
# I       Anna              4.5              4.0              4.1
# II      Luis              3.8              3.5              3.1
# III    Pedro              4.2              4.7              4.7
# IV     María              3.0              3.6              4.0
# V     Carlos              4.8              4.9              3.8
# VI     Sofía              2.9              3.2              3.8
# VII     José              3.7              4.0              4.2
# VIII   Elena              4.1              4.3              5.0
# IX      Juan              4.0              3.9              3.0
# X      Lucía              3.3              3.1              3.2

# %%
media1= df_decimals['Qualification 1'].mean()
media2= df_decimals['Qualification 2'].mean()
media3= df_decimals['Qualification 3'].mean()
print(media1)
print(media2)
print(media3)
# Out:
# 3.8299999999999996
# 3.9200000000000004
# 3.8899999999999997

# %%
median1= df_decimals['Qualification 1'].median()
median2= df_decimals['Qualification 2'].median()
median3= df_decimals['Qualification 3'].median()
print(median1)
print(median2)
print(median3)
# Out:
# 3.9
# 3.95
# 3.9

# %%
Std1= df_decimals['Qualification 3'].std()
Std2= df_decimals['Qualification 3'].std()
Std3= df_decimals['Qualification 3'].std()
print(Std1)
print(Std2)
print(Std3)
# Out:
# 0.6624030327359453
# 0.6624030327359453
# 0.6624030327359453

# %%
Max1= df_decimals['Qualification 1'].max()
Max2= df_decimals['Qualification 2'].max()
Max3= df_decimals['Qualification 3'].max()
print(Max1)
print(Max2)
print(Max3)
# Out:
# 4.8
# 4.9
# 5.0

# %%
Min1= df_decimals['Qualification 1'].min()
Min2= df_decimals['Qualification 2'].min()
Min3= df_decimals['Qualification 3'].min()
print(Min1)
print(Min2)
print(Min3)
# Out:
# 2.9
# 3.1
# 3.0

# %%
df_decimals.describe()
print(df_decimals)
# Out:
#        Pupil  Qualification 1  Qualification 2  Qualification 3
# I       Anna              4.5              4.0              4.1
# II      Luis              3.8              3.5              3.1
# III    Pedro              4.2              4.7              4.7
# IV     María              3.0              3.6              4.0
# V     Carlos              4.8              4.9              3.8
# VI     Sofía              2.9              3.2              3.8
# VII     José              3.7              4.0              4.2
# VIII   Elena              4.1              4.3              5.0
# IX      Juan              4.0              3.9              3.0
# X      Lucía              3.3              3.1              3.2

# %%
df_decimals['Qualification 3'] = df_decimals['Qualification 3'].replace({
    4.1: 3.5,
    3.1: 4.0,
    4.7: 5.0,
    4.0: 3.8,
    3.8: 4.5,
    3.8: 3.7,
    4.2: 4.6,
    5.0: 4.3,
    3.0: 2.8,
    3.2: 2.3,
})
print(df_decimals)
# Out:
#        Pupil  Qualification 1  Qualification 2  Qualification 3
# I       Anna              4.5              4.0              3.5
# II      Luis              3.8              3.5              4.0
# III    Pedro              4.2              4.7              5.0
# IV     María              3.0              3.6              3.8
# V     Carlos              4.8              4.9              3.7
# VI     Sofía              2.9              3.2              3.7
# VII     José              3.7              4.0              4.6
# VIII   Elena              4.1              4.3              4.3
# IX      Juan              4.0              3.9              2.8
# X      Lucía              3.3              3.1              2.3

# %%
df_decimals= df_decimals.drop(columns=['Qualification 3'])
print (df_decimals)
# Out:
#        Pupil  Qualification 1  Qualification 2
# I       Anna              4.5              4.0
# II      Luis              3.8              3.5
# III    Pedro              4.2              4.7
# IV     María              3.0              3.6
# V     Carlos              4.8              4.9
# VI     Sofía              2.9              3.2
# VII     José              3.7              4.0
# VIII   Elena              4.1              4.3
# IX      Juan              4.0              3.9
# X      Lucía              3.3              3.1

# %%
df_decimals= df_decimals.drop(index = 'VIII')
print (df_decimals)
# Out:
#       Pupil  Qualification 1  Qualification 2
# I      Anna              4.5              4.0
# II     Luis              3.8              3.5
# III   Pedro              4.2              4.7
# IV    María              3.0              3.6
# V    Carlos              4.8              4.9
# VI    Sofía              2.9              3.2
# VII    José              3.7              4.0
# IX     Juan              4.0              3.9
# X     Lucía              3.3              3.1

# %% [markdown]
# # *DataFrame Cadenas de Texto*

# %%
df_text = pd.DataFrame([['Cien años de soledad', 'Gabriel García Márquez'],['La sombra del viento', 'Carlos Ruiz Zafón'],['El amor en los tiempos del cólera', 'Gabriel García Márquez'],['Rayuela', 'Julio Cortázar'],['Pedro Páramo', 'Juan Rulfo'], ['Ficciones', 'Jorge Luis Borges'],['Don Quijote de la Mancha', 'Miguel de Cervantes'], ['La tregua', 'Mario Benedetti'], ['El túnel', 'Ernesto Sabato'],['Crónica de una muerte anunciada', 'Gabriel García Márquez']], columns=['Title', 'Author'], index=['1ro', '2do', '3ro', '4to', '5to', '6to', '7mo', '8vo', '9no', '10mo'])
print(df_text)
# Out:
#                                   Title                  Author
# 1ro                Cien años de soledad  Gabriel García Márquez
# 2do                La sombra del viento       Carlos Ruiz Zafón
# 3ro   El amor en los tiempos del cólera  Gabriel García Márquez
# 4to                             Rayuela          Julio Cortázar
# 5to                        Pedro Páramo              Juan Rulfo
# 6to                           Ficciones       Jorge Luis Borges
# 7mo            Don Quijote de la Mancha     Miguel de Cervantes
# 8vo                           La tregua         Mario Benedetti
# 9no                            El túnel          Ernesto Sabato
# 10mo    Crónica de una muerte anunciada  Gabriel García Márquez

# %%
df_text.head()
# Out:
#                                  Title                  Author
# 1ro               Cien años de soledad  Gabriel García Márquez
# 2do               La sombra del viento       Carlos Ruiz Zafón
# 3ro  El amor en los tiempos del cólera  Gabriel García Márquez
# 4to                            Rayuela          Julio Cortázar
# 5to                       Pedro Páramo              Juan Rulfo

# %%
df_text.tail()
# Out:
#                                 Title                  Author
# 6to                         Ficciones       Jorge Luis Borges
# 7mo          Don Quijote de la Mancha     Miguel de Cervantes
# 8vo                         La tregua         Mario Benedetti
# 9no                          El túnel          Ernesto Sabato
# 10mo  Crónica de una muerte anunciada  Gabriel García Márquez

# %%
df_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1ro to 10mo
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   10 non-null     object
#  1   Author  10 non-null     object
# dtypes: object(2)
# memory usage: 540.0+ bytes

# %%
df_text.dtypes
# Out:
# Title     object
# Author    object
# dtype: object

# %%
df_text.columns = ['Book_name', 'Writer']
print(df_text)
# Out:
#                               Book_name                  Writer
# 1ro                Cien años de soledad  Gabriel García Márquez
# 2do                La sombra del viento       Carlos Ruiz Zafón
# 3ro   El amor en los tiempos del cólera  Gabriel García Márquez
# 4to                             Rayuela          Julio Cortázar
# 5to                        Pedro Páramo              Juan Rulfo
# 6to                           Ficciones       Jorge Luis Borges
# 7mo            Don Quijote de la Mancha     Miguel de Cervantes
# 8vo                           La tregua         Mario Benedetti
# 9no                            El túnel          Ernesto Sabato
# 10mo    Crónica de una muerte anunciada  Gabriel García Márquez

# %%
names = df_text['Writer']
print(names)
# Out:
# 1ro     Gabriel García Márquez
# 2do          Carlos Ruiz Zafón
# 3ro     Gabriel García Márquez
# 4to             Julio Cortázar
# 5to                 Juan Rulfo
# 6to          Jorge Luis Borges
# 7mo        Miguel de Cervantes
# 8vo            Mario Benedetti
# 9no             Ernesto Sabato
# 10mo    Gabriel García Márquez
# Name: Writer, dtype: object

# %%
df_text[['Book_name', 'Writer']]
# Out:
#                               Book_name                  Writer
# 1ro                Cien años de soledad  Gabriel García Márquez
# 2do                La sombra del viento       Carlos Ruiz Zafón
# 3ro   El amor en los tiempos del cólera  Gabriel García Márquez
# 4to                             Rayuela          Julio Cortázar
# 5to                        Pedro Páramo              Juan Rulfo
# 6to                           Ficciones       Jorge Luis Borges
# 7mo            Don Quijote de la Mancha     Miguel de Cervantes
# 8vo                           La tregua         Mario Benedetti
# 9no                            El túnel          Ernesto Sabato
# 10mo    Crónica de una muerte anunciada  Gabriel García Márquez

# %%
df_text[df_text['Book_name'] == 'El amor en los tiempos del cólera']
# Out:
#                              Book_name                  Writer
# 3ro  El amor en los tiempos del cólera  Gabriel García Márquez

# %%
df_text.loc['4to']
# Out:
# Book_name           Rayuela
# Writer       Julio Cortázar
# Name: 4to, dtype: object

# %%
df_text[(df_text['Book_name'] == 'Ficciones') | (df_text['Writer'] == 'Gabriel García Márquez')]
df_text[(df_text['Book_name']=='Ficciones' ) & (df_text['Writer'] == 'Jorge Luis Borges')]
# Out:
#      Book_name             Writer
# 6to  Ficciones  Jorge Luis Borges

# %%
df_text['Book_genre'] = ['Realismo Mágico', 'Misterio', 'Realismo Mágico', 'Vanguardismo', 'Realismo Mágico', 'Ficción', 'Novela', 'Romance', 'Psicológico', 'Realismo Mágico']
print(df_text)
# Out:
#                               Book_name                  Writer  \
# 1ro                Cien años de soledad  Gabriel García Márquez
# 2do                La sombra del viento       Carlos Ruiz Zafón
# 3ro   El amor en los tiempos del cólera  Gabriel García Márquez
# 4to                             Rayuela          Julio Cortázar
# 5to                        Pedro Páramo              Juan Rulfo
# 6to                           Ficciones       Jorge Luis Borges
# 7mo            Don Quijote de la Mancha     Miguel de Cervantes
# 8vo                           La tregua         Mario Benedetti
# 9no                            El túnel          Ernesto Sabato
# 10mo    Crónica de una muerte anunciada  Gabriel García Márquez
#
#            Book_genre
# 1ro   Realismo Mágico
# 2do          Misterio
# 3ro   Realismo Mágico
# 4to      Vanguardismo
# 5to   Realismo Mágico
# 6to           Ficción
# 7mo            Novela
# 8vo           Romance
# 9no       Psicológico
# 10mo  Realismo Mágico

# %%
df_text['Writer'] = df_text['Writer'].replace({
    'Gabriel García Márquez': 'Gabo',
    'Carlos Ruiz Zafón': 'Ruiz Zafón',
    'Julio Cortázar': 'JuCa',
    'Juan Rulfo': 'Juano',
    'Jorge Luis Borges': 'Borges',
    'Miguel de Cervantes': 'Cervantes',
    'Mario Benedetti': 'Bene',
    'Ernesto Sabato': 'Sabato'})

print(df_text)
# Out:
#                               Book_name      Writer       Book_genre
# 1ro                Cien años de soledad        Gabo  Realismo Mágico
# 2do                La sombra del viento  Ruiz Zafón         Misterio
# 3ro   El amor en los tiempos del cólera        Gabo  Realismo Mágico
# 4to                             Rayuela        JuCa     Vanguardismo
# 5to                        Pedro Páramo       Juano  Realismo Mágico
# 6to                           Ficciones      Borges          Ficción
# 7mo            Don Quijote de la Mancha   Cervantes           Novela
# 8vo                           La tregua        Bene          Romance
# 9no                            El túnel      Sabato      Psicológico
# 10mo    Crónica de una muerte anunciada        Gabo  Realismo Mágico

# %%
df_text = df_text.drop(columns='Book_genre')
print(df_text)
# Out:
#                               Book_name      Writer
# 1ro                Cien años de soledad        Gabo
# 2do                La sombra del viento  Ruiz Zafón
# 3ro   El amor en los tiempos del cólera        Gabo
# 4to                             Rayuela        JuCa
# 5to                        Pedro Páramo       Juano
# 6to                           Ficciones      Borges
# 7mo            Don Quijote de la Mancha   Cervantes
# 8vo                           La tregua        Bene
# 9no                            El túnel      Sabato
# 10mo    Crónica de una muerte anunciada        Gabo

# %%
df_text = df_text.drop(index='5to')
print(df_text)
# Out:
#                               Book_name      Writer
# 1ro                Cien años de soledad        Gabo
# 2do                La sombra del viento  Ruiz Zafón
# 3ro   El amor en los tiempos del cólera        Gabo
# 4to                             Rayuela        JuCa
# 6to                           Ficciones      Borges
# 7mo            Don Quijote de la Mancha   Cervantes
# 8vo                           La tregua        Bene
# 9no                            El túnel      Sabato
# 10mo    Crónica de una muerte anunciada        Gabo
